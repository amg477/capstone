# %% [markdown]
# # PCA EDA

# %% [markdown]
# **ASSIGNED: MOHAMMAD**

# %% [markdown]
# ## Setup

# %%
# Load Packages
import pandas as pd

# %%
# Load Data
df = pd.read_parquet("../data_storage/final_data/attribution_dataset.parquet")

# %% [markdown]
# ## Analysis
